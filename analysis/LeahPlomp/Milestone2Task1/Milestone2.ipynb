# %%
import pandas as pd
import seaborn as sns
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importing Data from local file and creating DataFrame, save DataFrame as object,df.

pd.read_csv("../../../Data/Raw/impacts.csv")
df=pd.read_csv("../../../Data/Raw/impacts.csv")

# %%
df
# Out:
#                   Object Name  Period Start  Period End  Possible Impacts  \
# 0                    2006 WP1          2017        2017                 1
# 1                     2013 YB          2017        2046                23
# 2                     2008 US          2017        2062                30
# 3                  2010 VR139          2017        2076                24
# 4                  2015 ME131          2017        2096                85
# ..                        ...           ...         ...               ...
# 678                 2014 KW76          2115        2115                 1
# 679                   2012 FN          2115        2115                 1
# 680  101955 Bennu (1999 RQ36)          2175        2199                78
# 681          410777 (2009 FD)          2185        2198                 7
# 682           29075 (1950 DA)          2880        2880                 1
#
#      Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# ...

# %%
#Checking details of Dataset, using shape command to see row details

# %%
df.shape
# Out:
# (683, 11)

# %%
df.columns
# Out:
# Index(['Object Name', 'Period Start', 'Period End', 'Possible Impacts',
#        'Cumulative Impact Probability', 'Asteroid Velocity',
#        'Asteroid Magnitude', 'Asteroid Diameter (km)',
#        'Cumulative Palermo Scale', 'Maximum Palermo Scale',
#        'Maximum Torino Scale'],
#       dtype='object')

# %%
new_names= {"Object Name": "Asteroid Name",
           "Period Start": "Risk Period Start", 
           "Period End": "Risk Period End",
           "Asteroid Velocity": "Asteroid Velocity (Km/s)",
           "Asteroid Magnitude": "Asteroid Apparent Magnitude"}

# %%
df.rename(columns=new_names, inplace=True)

# %%
df.columns
# Out:
# Index(['Asteroid Name', 'Risk Period Start', 'Risk Period End',
#        'Possible Impacts', 'Cumulative Impact Probability',
#        'Asteroid Velocity (Km/s)', 'Asteroid Apparent Magnitude',
#        'Asteroid Diameter (km)', 'Cumulative Palermo Scale',
#        'Maximum Palermo Scale', 'Maximum Torino Scale'],
#       dtype='object')

# %%
df.drop("Maximum Torino Scale", inplace=True, axis=1)

# %%
df.columns
# Out:
# Index(['Asteroid Name', 'Risk Period Start', 'Risk Period End',
#        'Possible Impacts', 'Cumulative Impact Probability',
#        'Asteroid Velocity (Km/s)', 'Asteroid Apparent Magnitude',
#        'Asteroid Diameter (km)', 'Cumulative Palermo Scale',
#        'Maximum Palermo Scale'],
#       dtype='object')

# %%
df.head()
# Out:
#   Asteroid Name  Risk Period Start  Risk Period End  Possible Impacts  \
# 0      2006 WP1               2017             2017                 1
# 1       2013 YB               2017             2046                23
# 2       2008 US               2017             2062                30
# 3    2010 VR139               2017             2076                24
# 4    2015 ME131               2017             2096                85
#
#    Cumulative Impact Probability  Asteroid Velocity (Km/s)  \
# 0                   5.200000e-09                     17.77
# 1                   7.600000e-05                      8.98
# 2                   1.600000e-05                     18.33
# 3                   2.000000e-07                      4.99
# 4                   2.300000e-08                     19.46
#
#    Asteroid Apparent Magnitude  Asteroid Diameter (km)  \
# 0                         28.3                   0.007
# 1                         31.4                   0.002
# ...

# %%
#Checking for duplicate data

df["Asteroid Name"].is_unique
# Out:
# True

# %%
#No Duplicate Asteroids in Data, Setting Index to Asteroid Name Column 

df=df.set_index("Asteroid Name")

# %%
df.head()
# Out:
#   Object Name  Period Start  Period End  Possible Impacts  \
# 0    2006 WP1          2017        2017                 1
# 1     2013 YB          2017        2046                23
# 2     2008 US          2017        2062                30
# 3  2010 VR139          2017        2076                24
# 4  2015 ME131          2017        2096                85
#
#    Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# 0                   5.200000e-09              17.77                28.3
# 1                   7.600000e-05               8.98                31.4
# 2                   1.600000e-05              18.33                31.4
# 3                   2.000000e-07               4.99                26.7
# 4                   2.300000e-08              19.46                19.2
#
#    Asteroid Diameter (km)  Cumulative Palermo Scale  Maximum Palermo Scale  \
# 0                   0.007                     -8.31                  -8.31
# ...

# %%
df.shape
# Out:
# (683, 9)

# %%
df.dtypes.value_counts()
# Out:
# float64    6
# int64      3
# dtype: int64

# %%
df
# Out:
#                   Object Name  Period Start  Period End  Possible Impacts  \
# 0                    2006 WP1          2017        2017                 1
# 1                     2013 YB          2017        2046                23
# 2                     2008 US          2017        2062                30
# 3                  2010 VR139          2017        2076                24
# 4                  2015 ME131          2017        2096                85
# ..                        ...           ...         ...               ...
# 678                 2014 KW76          2115        2115                 1
# 679                   2012 FN          2115        2115                 1
# 680  101955 Bennu (1999 RQ36)          2175        2199                78
# 681          410777 (2009 FD)          2185        2198                 7
# 682           29075 (1950 DA)          2880        2880                 1
#
#      Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# ...

# %%
df.head()
# Out:
#   Asteroid Name  Risk Period Start  Risk Period End  Possible Impacts  \
# 0      2006 WP1               2017             2017                 1
# 1       2013 YB               2017             2046                23
# 2       2008 US               2017             2062                30
# 3    2010 VR139               2017             2076                24
# 4    2015 ME131               2017             2096                85
#
#    Cumulative Impact Probability  Asteroid Velocity (Km/s)  \
# 0                   5.200000e-09                     17.77
# 1                   7.600000e-05                      8.98
# 2                   1.600000e-05                     18.33
# 3                   2.000000e-07                      4.99
# 4                   2.300000e-08                     19.46
#
#    Asteroid Apparent Magnitude  Asteroid Diameter (km)  \
# 0                         28.3                   0.007
# 1                         31.4                   0.002
# ...

# %%
df = (pd.read_csv("../../../Data/Raw/impacts.csv")
    .rename(columns= {"Object Name": "Asteroid Name",
           "Period Start": "Risk Period Start", 
           "Period End": "Risk Period End",
           "Asteroid Velocity": "Asteroid Velocity (Km/s)",
           "Asteroid Magnitude": "Asteroid Apparent Magnitude"})
      .drop(['Maximum Torino Scale'], axis=1)
      .loc[0:648]
      .set_index("Asteroid Name")
      .sort_values(by='Risk Period Start',ascending=True)
     )
df
# Out:
#                Risk Period Start  Risk Period End  Possible Impacts  \
# Asteroid Name
# 2006 WP1                    2017             2017                 1
# 2008 EK68                   2017             2115               315
# 2012 BP123                  2017             2115               228
# 2015 HW182                  2017             2115               174
# 2010 WW8                    2017             2114                92
# ...                          ...              ...               ...
# 2015 FC345                  2109             2109                 1
# 2014 QJ365                  2109             2109                 1
# 2016 AU193                  2109             2109                 1
# 2008 OO8                    2109             2109                 1
# 2014 OQ392                  2109             2109                 1
#
#                Cumulative Impact Probability  Asteroid Velocity (Km/s)  \
# Asteroid Name
# ...

# %%
def load_and_process(project_function):
                     
    # Method Chain 1 (Load Data, Rename Columns, Drop Unused Column)

    df = (pd.read_csv("../../../Data/Raw/impacts.csv")
           .rename(columns= {"Object Name": "Asteroid Name",
           "Period Start": "Risk Period Start", 
           "Period End": "Risk Period End",
           "Asteroid Velocity": "Asteroid Velocity (Km/s)",
           "Asteroid Magnitude": "Asteroid Apparent Magnitude"})
           .drop(['maximum Torino Scale'], axis=1)
     )
    
    # Method Chain 2 (Sort Values, Index Asteroid Name, Retrieve rows from index)
                     
    df = (
           df
          .sort_values(by='Risk Period Start', ascending=True)
          .loc[0:648]
    )
    return df

# %%
import pandas as pd

# %%
impacts=pd.DataFrame((list)'impacts.csv')
# Out:
#   File "C:\Users\Leah\AppData\Local\Temp/ipykernel_23400/4225308237.py", line 1
#     impacts=pd.DataFrame((list)'impacts.csv')
#                                ^
# SyntaxError: invalid syntax

# %%
"collection[Any]"
# Out:
# 'collection[Any]'

# %%
df=pd.DataFrame(["../impacts.csv"])

# %%
def load_and_process(df):
                     
    # Method Chain 1 (Load Data, Rename Columns, Drop Unused Column)

    df = (pd.read_csv("impacts.csv")
           .rename(columns= {"Object Name": "Asteroid Name",
           "Period Start": "Risk Period Start", 
           "Period End": "Risk Period End",
           "Asteroid Velocity": "Asteroid Velocity (Km/s)",
           "Asteroid Magnitude": "Asteroid Apparent Magnitude"})
           .drop('Maximum Torino Scale', axis=1)
     )
    
    # Method Chain 2 (Sort Values, Index Asteroid Name, Retrieve rows from index)
                     
    df = (
           df
          .sort_values(by='Risk Period Start', ascending=True)
          .loc[0:648]
    )
    return df

# %%
type(load_and_process(df))
# Out:
# pandas.core.frame.DataFrame

# %%
pwd
# Out:
# 'C:\\Users\\Leah\\Data 301\\Group 43\\Group-43-project\\analysis\\LeahPlomp\\Milestone2Task1'

# %%
cd ..
# Out:
# C:\Users\Leah\Data 301\Group 43\Group-43-project\analysis\LeahPlomp

# %%
impacts=pd.read_csv("impacts.csv")

# %%
type(impacts)
# Out:
# pandas.core.frame.DataFrame

# %%
impacts.head()
# Out:
#   Object Name  Period Start  Period End  Possible Impacts  \
# 0    2006 WP1          2017        2017                 1
# 1     2013 YB          2017        2046                23
# 2     2008 US          2017        2062                30
# 3  2010 VR139          2017        2076                24
# 4  2015 ME131          2017        2096                85
#
#    Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# 0                   5.200000e-09              17.77                28.3
# 1                   7.600000e-05               8.98                31.4
# 2                   1.600000e-05              18.33                31.4
# 3                   2.000000e-07               4.99                26.7
# 4                   2.300000e-08              19.46                19.2
#
#    Asteroid Diameter (km)  Cumulative Palermo Scale  Maximum Palermo Scale  \
# 0                   0.007                     -8.31                  -8.31
# ...

# %%
def load_and_process("impacts.csv"):
                     
    # Method Chain 1 (Load Data, Rename Columns, Drop Unused Column)

    impacts = (pd.read_csv("impacts.csv")
           .rename(columns= {"Object Name": "Asteroid Name",
           "Period Start": "Risk Period Start", 
           "Period End": "Risk Period End",
           "Asteroid Velocity": "Asteroid Velocity (Km/s)",
           "Asteroid Magnitude": "Asteroid Apparent Magnitude"})
           .drop(['Maximum Torino Scale'], axis=1)
     )
    
    # Method Chain 2 (Sort Values, Index Asteroid Name, Retrieve rows from index)
                     
    impacts = (
           impacts
          .sort_values(by='Risk Period Start', ascending=True)
          .loc[0:648]
    )
# Out:
#   File "C:\Users\Leah\AppData\Local\Temp/ipykernel_23400/3720535040.py", line 1
#     def load_and_process("impacts.csv"):
#                          ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23400/1733582095.py in <module>
# ----> 1 print.impacts
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'impacts'

# %%
type(impacts)
# Out:
# pandas.core.frame.DataFrame

# %%
impacts
# Out:
#                   Object Name  Period Start  Period End  Possible Impacts  \
# 0                    2006 WP1          2017        2017                 1
# 1                     2013 YB          2017        2046                23
# 2                     2008 US          2017        2062                30
# 3                  2010 VR139          2017        2076                24
# 4                  2015 ME131          2017        2096                85
# ..                        ...           ...         ...               ...
# 678                 2014 KW76          2115        2115                 1
# 679                   2012 FN          2115        2115                 1
# 680  101955 Bennu (1999 RQ36)          2175        2199                78
# 681          410777 (2009 FD)          2185        2198                 7
# 682           29075 (1950 DA)          2880        2880                 1
#
#      Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# ...

# %%
type(load_and_process(impacts))
# Out:
# pandas.core.frame.DataFrame

# %%
load_and_process(impacts)
# Out:
#     Asteroid Name  Risk Period Start  Risk Period End  Possible Impacts  \
# 0        2006 WP1               2017             2017                 1
# 25      2008 EK68               2017             2115               315
# 24     2012 BP123               2017             2115               228
# 23     2015 HW182               2017             2115               174
# 21       2010 WW8               2017             2114                92
# ..            ...                ...              ...               ...
# 644    2016 AU193               2109             2109                 1
# 645      2008 OO8               2109             2109                 1
# 646    2015 FC345               2109             2109                 1
# 647    2014 QJ365               2109             2109                 1
# 648    2014 OQ392               2109             2109                 1
#
#      Cumulative Impact Probability  Asteroid Velocity (Km/s)  \
# ...

# %%
import sys
sys.path.append('..')

from scripts import project_functions
impacts = project_functions.load_and_process(impacts)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22936/2281514115.py in <module>
#       3
#       4 from scripts import project_functions
# ----> 5 impacts = project_functions.load_and_process(impacts)
#       6
#
# ~\Data 301\Group 43\Group-43-project\analysis\LeahPlomp\scripts\project_functions.py in load_and_process(impacts)
#       9
#      10     # Method Chain 1 (Load Data, Rename Columns, Drop Unused Column)
# ---> 11
#      12     impacts = (pd.read_csv("impacts.csv")
#      13            .rename(columns= {"Object Name": "Asteroid Name",
#
# ~\miniconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
impacts
# Out:
# <module 'scripts.project_functions' from '..\\scripts\\project_functions.py'>
